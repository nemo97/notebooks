# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from patsy import dmatrices
from sklearn.linear_model import LogisticRegression

# %%
data = sm.datasets.fair.load_pandas().data
vars = ['age','religious','affairs']
data = data[vars]
data
# Out:
#        age  religious    affairs
# 0     32.0        3.0   0.111111
# 1     27.0        1.0   3.230769
# 2     22.0        1.0   1.400000
# 3     37.0        3.0   0.727273
# 4     27.0        1.0   4.666666
# 5     27.0        2.0   4.666666
# 6     37.0        2.0   0.852174
# 7     37.0        2.0   1.826086
# 8     22.0        2.0   4.799999
# 9     27.0        1.0   1.333333
# 10    27.0        1.0   3.266665
# 11    27.0        3.0   2.041666
# 12    37.0        1.0   0.484848
# 13    27.0        2.0   2.000000
# 14    22.0        1.0   3.266665
# 15    37.0        2.0   1.361111
# 16    27.0        1.0   2.000000
# 17    37.0        4.0   1.826086
# 18    42.0        2.0   1.826086
# 19    37.0        2.0   2.041666
# 20    22.0        2.0   7.839996
# 21    37.0        2.0   2.545454
# 22    42.0        3.0   0.532609
# 23    27.0        4.0   0.622222
# 24    27.0        2.0   0.583333
# 25    27.0        3.0   4.799999
# 26    27.0        2.0   0.166667
# 27    37.0        3.0   0.615385
# 28    32.0        2.0   1.187878
# 29    27.0        1.0  11.199999
# ...    ...        ...        ...
# 6336  42.0        3.0   0.000000
# 6337  27.0        4.0   0.000000
# 6338  42.0        3.0   0.000000
# 6339  32.0        3.0   0.000000
# 6340  27.0        3.0   0.000000
# 6341  27.0        2.0   0.000000
# 6342  22.0        2.0   0.000000
# 6343  17.5        4.0   0.000000
# 6344  32.0        2.0   0.000000
# 6345  27.0        3.0   0.000000
# 6346  22.0        4.0   0.000000
# 6347  22.0        2.0   0.000000
# 6348  27.0        4.0   0.000000
# 6349  37.0        3.0   0.000000
# 6350  32.0        4.0   0.000000
# 6351  22.0        2.0   0.000000
# 6352  42.0        4.0   0.000000
# 6353  22.0        2.0   0.000000
# 6354  42.0        4.0   0.000000
# 6355  27.0        3.0   0.000000
# 6356  32.0        3.0   0.000000
# 6357  32.0        2.0   0.000000
# 6358  27.0        4.0   0.000000
# 6359  22.0        3.0   0.000000
# 6360  22.0        2.0   0.000000
# 6361  32.0        3.0   0.000000
# 6362  32.0        1.0   0.000000
# 6363  22.0        2.0   0.000000
# 6364  32.0        3.0   0.000000
# 6365  22.0        2.0   0.000000
#
# [6366 rows x 3 columns]

# %%
data.groupby('age').mean()
# Out:
#       religious   affairs
# age
# 17.5   2.366906  0.645324
# 22.0   2.336111  0.928274
# 27.0   2.328845  0.819545
# 32.0   2.475210  0.548795
# 37.0   2.586751  0.448880
# 42.0   2.683480  0.348074

# %%
y,X = dmatrices('affairs ~ age + religious',data)
y,X
# Out:
# (DesignMatrix with shape (6366L, 1L)
#     affairs
#     0.11111
#     3.23077
#     1.40000
#     0.72727
#     4.66667
#     4.66667
#     0.85217
#     1.82609
#     4.80000
#     1.33333
#     3.26666
#     2.04167
#     0.48485
#     2.00000
#     3.26666
#     1.36111
#     2.00000
#     1.82609
#     1.82609
#     2.04167
#     7.84000
#     2.54545
#     0.53261
#     0.62222
#     0.58333
#     4.80000
#     0.16667
#     0.61538
#     1.18788
#    11.20000
#    [6336 rows omitted]
#    Terms:
#      'affairs' (column 0)
#    (to view full data, use np.asarray(this_obj)),
#  DesignMatrix with shape (6366L, 3L)
#    Intercept  age  religious
#            1   32          3
#            1   27          1
#            1   22          1
#            1   37          3
#            1   27          1
#            1   27          2
#            1   37          2
#            1   37          2
#            1   22          2
#            1   27          1
#            1   27          1
#            1   27          3
#            1   37          1
#            1   27          2
#            1   22          1
#            1   37          2
#            1   27          1
#            1   37          4
#            1   42          2
#            1   37          2
#            1   22          2
#            1   37          2
#            1   42          3
#            1   27          4
#            1   27          2
#            1   27          3
#            1   27          2
#            1   37          3
#            1   32          2
#            1   27          1
#    [6336 rows omitted]
#    Terms:
#      'Intercept' (column 0)
#      'age' (column 1)
#      'religious' (column 2)
#    (to view full data, use np.asarray(this_obj)))

# %%
# instantiate a logistic regression model, and fit with X and y
model = LogisticRegression()
model=model.fit(X,np.ravel(y))
# Out:
# ValueErrorTraceback (most recent call last)
# <ipython-input-43-437a16471753> in <module>()
#       1 # instantiate a logistic regression model, and fit with X and y
#       2 model = LogisticRegression()
# ----> 3 model=model.fit(X,np.ravel(y))
#
# C:\Anaconda2\lib\site-packages\sklearn\linear_model\logistic.pyc in fit(self, X, y, sample_weight)
#    1172         X, y = check_X_y(X, y, accept_sparse='csr', dtype=np.float64,
#    1173                          order="C")
# -> 1174         check_classification_targets(y)
#    1175         self.classes_ = np.unique(y)
#    1176         n_samples, n_features = X.shape
#
# C:\Anaconda2\lib\site-packages\sklearn\utils\multiclass.pyc in check_classification_targets(y)
#     170     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     171             'multilabel-indicator', 'multilabel-sequences']:
# --> 172         raise ValueError("Unknown label type: %r" % y_type)
#     173
#     174
#
# ValueError: Unknown label type: 'continuous'
